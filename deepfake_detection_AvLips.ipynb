# %%
import os, gc, torch
torch.cuda.empty_cache()
gc.collect()
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

try:
    del model_0, optimizer, loss_fn
except Exception as e:
    pass
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
import torch
import gdown
import zipfile
from pathlib import Path

data_dir = "data"
dataset_name = "Lipsync.zip"
data_path = Path(data_dir)
dataset_folder_path = data_path / dataset_name.replace(".zip", "")

file_id = "1A1S944CmIowWoBth35O1ydjaxfsrU9Sc"

if dataset_folder_path.is_dir():
    print(f"{dataset_folder_path} directory already exists.")
else:
    print(f"Did not find {dataset_folder_path} directory, creating one...")
    dataset_folder_path.mkdir(parents=True, exist_ok=True)
    zip_path = data_path / dataset_name
    print(f"Downloading {dataset_name} dataset from Google Drive...")
    gdown.download(f'https://drive.google.com/uc?id={file_id}', str(zip_path), quiet=False)
    print(f"Unzipping {dataset_name}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(data_path)
    print(f"Dataset {dataset_name} downloaded and extracted successfully.")

print(f"PyTorch version: {torch.__version__}")
# Out:
# data/Lipsync directory already exists.
# PyTorch version: 2.2.1+cu121

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
torch.backends.cudnn.benchmark = True
# Out:
# Using device: cuda

# %%
from pathlib import Path
import os

DATASET_FOLDER = Path("data/Lipsync")
REAL_VIDEOS = DATASET_FOLDER / "0_real"
FAKE_VIDEOS = DATASET_FOLDER / "1_fake"

real_videos_list = os.listdir(REAL_VIDEOS)
fake_videos_list = os.listdir(FAKE_VIDEOS)

print(f"Number of REAL videos: {len(real_videos_list)}")
print(f"Number of FAKE videos: {len(fake_videos_list)}")

def get_video_paths_and_labels(real_videos, fake_videos):
    real_paths = [os.path.join(REAL_VIDEOS, video) for video in real_videos]
    fake_paths = [os.path.join(FAKE_VIDEOS, video) for video in fake_videos]
    video_paths = real_paths + fake_paths
    labels = [0] * len(real_paths) + [1] * len(fake_paths)  # {0 for REAL, 1 for FAKE}
    return video_paths, labels

video_paths, video_labels = get_video_paths_and_labels(real_videos_list, fake_videos_list)
print(f"Total videos: {len(video_paths)}, Total labels: {len(video_labels)}")
# Out:
# Number of REAL videos: 2686
# Number of FAKE videos: 3112
# Total videos: 5798, Total labels: 5798

# %%
import matplotlib.pyplot as plt

def visualize_data_distribution(labels):
    plt.figure(figsize=(6, 4))
    plt.hist(labels, bins=2, rwidth=0.8, color="skyblue")
    plt.xticks([0, 1], ["REAL", "FAKE"])
    plt.xlabel('Labels')
    plt.ylabel('Frequency')
    plt.title('Distribution of Labels (REAL vs FAKE)')
    plt.show()

visualize_data_distribution(video_labels)

# %%
from sklearn.model_selection import train_test_split

train_paths, test_paths, train_labels, test_labels = train_test_split(
    video_paths, 
    video_labels, 
    test_size=0.2, 
    stratify=video_labels, 
    random_state=42
)

print(f"Training samples: {len(train_paths)}, Testing samples: {len(test_paths)}")
# Out:
# Training samples: 4638, Testing samples: 1160

# %%
import cv2
import torch
from torchvision import transforms

IMG_SIZE = 224
MAX_NUM_FRAMES = 60

transform = transforms.Compose([
  transforms.ToPILImage(),
  transforms.Resize((IMG_SIZE, IMG_SIZE)),
  transforms.ToTensor(),
  transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def load_video(path, max_frames=MAX_NUM_FRAMES, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    #print(f"Tensor Frames: {total_frames}")
    frames = []
    
    if total_frames > 0:
        if total_frames >= max_frames:
            indices = [int(i * total_frames / max_frames) for i in range(max_frames)]
        else:
            indices = list(range(total_frames))
        
        frame_id = 0
        current_sample = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            if frame_id == indices[current_sample]:
                frame = cv2.resize(frame, resize)
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frame_tensor = transform(frame)
                frames.append(frame_tensor)
                current_sample += 1

                if current_sample >= len(indices):
                    break
            frame_id += 1
    cap.release()
    
    if len(frames) < max_frames:
        if frames:
            pad_frames = [torch.zeros_like(frames[0])] * (max_frames - len(frames))
        else:
            pad_frames = [torch.zeros(3, IMG_SIZE, IMG_SIZE)] * max_frames
        frames.extend(pad_frames)

    return torch.stack(frames)

# %%
sample_video_path = train_paths[0]
video_tensor = load_video(sample_video_path)
print(f"Video tensor shape: {video_tensor.shape}")
# Out:
# Video tensor shape: torch.Size([60, 3, 224, 224])

# %%
from torch.utils.data import Dataset, DataLoader

class VideoDataset(Dataset):
    def __init__(self, video_paths, labels):
        self.video_paths = video_paths
        self.labels = labels

    def __len__(self):
        return len(self.video_paths)

    def __getitem__(self, idx):
        video_path = self.video_paths[idx]
        label = self.labels[idx]
        video_tensor = load_video(video_path)
        return video_tensor, label

train_dataset = VideoDataset(train_paths, train_labels)
test_dataset = VideoDataset(test_paths, test_labels)
print(f"Training dataset: {len(train_dataset)}, Testing dataset: {len(test_dataset)}")
# Out:
# Training dataset: 4638, Testing dataset: 1160

# %%
BATCH_SIZE = 8
NUM_WORKERS = min(4, os.cpu_count() if os.cpu_count() is not None else 1)

train_dataloader = DataLoader(train_dataset, 
                            batch_size=BATCH_SIZE, 
                            shuffle=True, 
                            num_workers=NUM_WORKERS)

test_dataloader = DataLoader(test_dataset, 
                            batch_size=BATCH_SIZE, 
                            shuffle=False, 
                            num_workers=NUM_WORKERS)

print(f"Number of training batches: {len(train_dataloader)}")
print(f"Number of testing batches: {len(test_dataloader)}")

video_batch, label_batch = next(iter(train_dataloader))
print(f"Video batch shape: {video_batch.shape}, Label batch shape: {label_batch.shape}")
# Out:
# Number of training batches: 580
# Number of testing batches: 145
# Video batch shape: torch.Size([8, 60, 3, 224, 224]), Label batch shape: torch.Size([8])

# %%
import torch
from torch import nn
import torch.optim as optim
from torchvision.models import resnext50_32x4d, ResNeXt50_32X4D_Weights

class DeepFakeDetector(nn.Module):
    def __init__(self, hidden_size=2048, num_layers=1, dropout=0.4):
        super().__init__()
        
        weights = ResNeXt50_32X4D_Weights.DEFAULT
        resnext = resnext50_32x4d(weights=weights)

        self.cnn = nn.Sequential(
            *list(resnext.children())[:-2],
            nn.AdaptiveAvgPool2d((1, 1))      
        )

        self.cnn_fc = nn.Linear(2048, hidden_size)
        self.lstm = nn.LSTM(input_size=hidden_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            batch_first=True)

        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, video_tensor):
        batch_size, seq_len, c, h, w = video_tensor.shape
        video_features = []

        for t in range(seq_len):
            frame = video_tensor[:, t]  
            cnn_out = self.cnn(frame).view(batch_size, -1)
            video_features.append(self.cnn_fc(cnn_out))

        video_features = torch.stack(video_features, dim=1)  
        lstm_out, _ = self.lstm(video_features)
        lstm_out = self.dropout(lstm_out)
        final_output = lstm_out[:, -1, :]
        out = self.fc(final_output)
        return out

# %%
import sys
try:
    model_0 = DeepFakeDetector(hidden_size=2048, num_layers=1, dropout=0.4).to(device)
except RuntimeError as e:
    print("CUDA OOM error encountered during model instantiation. Switching model to CPU.")
    model_0 = DeepFakeDetector(hidden_size=2048, num_layers=1, dropout=0.4).to("cpu")
    device = "cpu"

model_0
# Out:
# DeepFakeDetector(
#   (cnn): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (cnn_fc): Linear(in_features=2048, out_features=2048, bias=True)
#   (lstm): LSTM(2048, 2048, batch_first=True)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )

# %%
video_batch, label_batch = next(iter(train_dataloader))
print(f"Video batch shape -> [batch_size, num_frames, 3, height, width]: {video_batch.shape}")
print(f"Label batch shape: {label_batch.shape}")
# Out:
# Video batch shape -> [batch_size, num_frames, 3, height, width]: torch.Size([8, 60, 3, 224, 224])
# Label batch shape: torch.Size([8])

# %%
#Model needs Input like this: [batch_size, num_frames, 3, height, width]
#choose single video(sequence of frames) and unsqueeze(add batch dimension)

video_single, label_single = video_batch[0].unsqueeze(dim=0), label_batch[0]
print(f"Single video shape (with batch dim): {video_single.shape}")
print(f"Single label: {label_single}")
# Out:
# Single video shape (with batch dim): torch.Size([1, 60, 3, 224, 224])
# Single label: 0

# %%
model_0.eval()
with torch.no_grad():
    pred = model_0(video_single.to(device))
    
pred_prob = torch.sigmoid(pred)
pred_label = (pred_prob > 0.5).float()

print(f"Output logits:\n{pred}\n")
print(f"Output prediction probabilities:\n{pred_prob}\n")
print(f"Output prediction label (FAKE=1, REAL=0): {pred_label.item()}\n")
print(f"Actual label (FAKE=1, REAL=0): {label_single.item()}")
# Out:
# Output logits:
# tensor([[-0.0237]], device='cuda:0')
#
# Output prediction probabilities:
# tensor([[0.4941]], device='cuda:0')
#
# Output prediction label (FAKE=1, REAL=0): 0.0
#
# Actual label (FAKE=1, REAL=0): 0

# %%
try:
    import torchinfo
except ImportError:
    # !pip install torchinfo
    import torchinfo
    
from torchinfo import summary
summary(model_0, input_size=[1, MAX_NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE])
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# DeepFakeDetector                              [1, 1]                    --
# ├─Sequential: 1-1                             [1, 2048, 1, 1]           --
# │    └─Conv2d: 2-1                            [1, 64, 112, 112]         9,408
# │    └─BatchNorm2d: 2-2                       [1, 64, 112, 112]         128
# │    └─ReLU: 2-3                              [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-4                         [1, 64, 56, 56]           --
# │    └─Sequential: 2-5                        [1, 256, 56, 56]          --
# │    │    └─Bottleneck: 3-1                   [1, 256, 56, 56]          63,488
# │    │    └─Bottleneck: 3-2                   [1, 256, 56, 56]          71,168
# │    │    └─Bottleneck: 3-3                   [1, 256, 56, 56]          71,168
# │    └─Sequential: 2-6                        [1, 512, 28, 28]          --
# │    │    └─Bottleneck: 3-4                   [1, 512, 28, 28]          349,184
# │    │    └─Bottleneck: 3-5                   [1, 512, 28, 28]          282,624
# │    │    └─Bottleneck: 3-6                   [1, 512, 28, 28]          282,624
# │    │    └─Bottleneck: 3-7                   [1, 512, 28, 28]          282,624
# │    └─Sequential: 2-7                        [1, 1024, 14, 14]         --
# │    │    └─Bottleneck: 3-8                   [1, 1024, 14, 14]         1,390,592
# │    │    └─Bottleneck: 3-9                   [1, 1024, 14, 14]         1,126,400
# │    │    └─Bottleneck: 3-10                  [1, 1024, 14, 14]         1,126,400
# │    │    └─Bottleneck: 3-11                  [1, 1024, 14, 14]         1,126,400
# │    │    └─Bottleneck: 3-12                  [1, 1024, 14, 14]         1,126,400
# │    │    └─Bottleneck: 3-13                  [1, 1024, 14, 14]         1,126,400
# │    └─Sequential: 2-8                        [1, 2048, 7, 7]           --
# │    │    └─Bottleneck: 3-14                  [1, 2048, 7, 7]           5,550,080
# │    │    └─Bottleneck: 3-15                  [1, 2048, 7, 7]           4,497,408
# │    │    └─Bottleneck: 3-16                  [1, 2048, 7, 7]           4,497,408
# │    └─AdaptiveAvgPool2d: 2-9                 [1, 2048, 1, 1]           --
# ├─Linear: 1-2                                 [1, 2048]                 4,196,352
# ├─Sequential: 1-3                             [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-10                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-11                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-12                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-13                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-14                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-17                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-18                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-19                  [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-15                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-20                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-21                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-22                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-23                  [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-16                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-24                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-25                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-26                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-27                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-28                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-29                  [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-17                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-30                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-31                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-32                  [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-18                [1, 2048, 1, 1]           --
# ├─Linear: 1-4                                 [1, 2048]                 (recursive)
# ├─Sequential: 1-5                             [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-19                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-20                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-21                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-22                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-23                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-33                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-34                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-35                  [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-24                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-36                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-37                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-38                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-39                  [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-25                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-40                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-41                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-42                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-43                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-44                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-45                  [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-26                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-46                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-47                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-48                  [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-27                [1, 2048, 1, 1]           --
# ├─Linear: 1-6                                 [1, 2048]                 (recursive)
# ├─Sequential: 1-7                             [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-28                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-29                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-30                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-31                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-32                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-49                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-50                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-51                  [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-33                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-52                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-53                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-54                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-55                  [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-34                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-56                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-57                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-58                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-59                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-60                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-61                  [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-35                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-62                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-63                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-64                  [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-36                [1, 2048, 1, 1]           --
# ├─Linear: 1-8                                 [1, 2048]                 (recursive)
# ├─Sequential: 1-9                             [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-37                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-38                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-39                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-40                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-41                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-65                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-66                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-67                  [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-42                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-68                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-69                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-70                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-71                  [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-43                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-72                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-73                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-74                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-75                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-76                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-77                  [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-44                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-78                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-79                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-80                  [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-45                [1, 2048, 1, 1]           --
# ├─Linear: 1-10                                [1, 2048]                 (recursive)
# ├─Sequential: 1-11                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-46                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-47                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-48                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-49                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-50                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-81                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-82                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-83                  [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-51                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-84                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-85                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-86                  [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-87                  [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-52                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-88                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-89                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-90                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-91                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-92                  [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-93                  [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-53                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-94                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-95                  [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-96                  [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-54                [1, 2048, 1, 1]           --
# ├─Linear: 1-12                                [1, 2048]                 (recursive)
# ├─Sequential: 1-13                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-55                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-56                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-57                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-58                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-59                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-97                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-98                  [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-99                  [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-60                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-100                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-101                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-102                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-103                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-61                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-104                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-105                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-106                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-107                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-108                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-109                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-62                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-110                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-111                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-112                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-63                [1, 2048, 1, 1]           --
# ├─Linear: 1-14                                [1, 2048]                 (recursive)
# ├─Sequential: 1-15                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-64                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-65                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-66                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-67                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-68                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-113                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-114                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-115                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-69                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-116                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-117                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-118                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-119                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-70                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-120                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-121                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-122                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-123                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-124                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-125                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-71                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-126                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-127                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-128                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-72                [1, 2048, 1, 1]           --
# ├─Linear: 1-16                                [1, 2048]                 (recursive)
# ├─Sequential: 1-17                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-73                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-74                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-75                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-76                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-77                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-129                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-130                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-131                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-78                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-132                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-133                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-134                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-135                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-79                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-136                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-137                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-138                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-139                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-140                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-141                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-80                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-142                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-143                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-144                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-81                [1, 2048, 1, 1]           --
# ├─Linear: 1-18                                [1, 2048]                 (recursive)
# ├─Sequential: 1-19                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-82                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-83                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-84                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-85                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-86                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-145                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-146                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-147                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-87                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-148                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-149                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-150                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-151                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-88                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-152                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-153                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-154                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-155                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-156                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-157                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-89                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-158                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-159                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-160                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-90                [1, 2048, 1, 1]           --
# ├─Linear: 1-20                                [1, 2048]                 (recursive)
# ├─Sequential: 1-21                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-91                           [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-92                      [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-93                             [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-94                        [1, 64, 56, 56]           --
# │    └─Sequential: 2-95                       [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-161                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-162                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-163                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-96                       [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-164                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-165                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-166                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-167                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-97                       [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-168                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-169                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-170                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-171                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-172                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-173                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-98                       [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-174                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-175                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-176                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-99                [1, 2048, 1, 1]           --
# ├─Linear: 1-22                                [1, 2048]                 (recursive)
# ├─Sequential: 1-23                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-100                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-101                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-102                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-103                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-104                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-177                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-178                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-179                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-105                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-180                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-181                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-182                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-183                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-106                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-184                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-185                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-186                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-187                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-188                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-189                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-107                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-190                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-191                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-192                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-108               [1, 2048, 1, 1]           --
# ├─Linear: 1-24                                [1, 2048]                 (recursive)
# ├─Sequential: 1-25                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-109                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-110                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-111                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-112                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-113                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-193                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-194                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-195                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-114                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-196                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-197                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-198                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-199                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-115                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-200                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-201                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-202                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-203                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-204                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-205                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-116                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-206                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-207                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-208                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-117               [1, 2048, 1, 1]           --
# ├─Linear: 1-26                                [1, 2048]                 (recursive)
# ├─Sequential: 1-27                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-118                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-119                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-120                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-121                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-122                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-209                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-210                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-211                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-123                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-212                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-213                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-214                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-215                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-124                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-216                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-217                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-218                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-219                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-220                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-221                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-125                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-222                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-223                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-224                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-126               [1, 2048, 1, 1]           --
# ├─Linear: 1-28                                [1, 2048]                 (recursive)
# ├─Sequential: 1-29                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-127                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-128                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-129                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-130                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-131                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-225                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-226                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-227                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-132                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-228                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-229                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-230                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-231                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-133                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-232                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-233                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-234                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-235                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-236                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-237                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-134                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-238                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-239                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-240                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-135               [1, 2048, 1, 1]           --
# ├─Linear: 1-30                                [1, 2048]                 (recursive)
# ├─Sequential: 1-31                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-136                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-137                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-138                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-139                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-140                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-241                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-242                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-243                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-141                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-244                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-245                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-246                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-247                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-142                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-248                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-249                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-250                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-251                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-252                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-253                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-143                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-254                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-255                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-256                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-144               [1, 2048, 1, 1]           --
# ├─Linear: 1-32                                [1, 2048]                 (recursive)
# ├─Sequential: 1-33                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-145                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-146                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-147                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-148                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-149                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-257                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-258                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-259                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-150                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-260                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-261                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-262                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-263                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-151                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-264                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-265                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-266                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-267                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-268                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-269                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-152                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-270                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-271                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-272                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-153               [1, 2048, 1, 1]           --
# ├─Linear: 1-34                                [1, 2048]                 (recursive)
# ├─Sequential: 1-35                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-154                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-155                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-156                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-157                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-158                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-273                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-274                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-275                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-159                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-276                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-277                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-278                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-279                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-160                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-280                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-281                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-282                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-283                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-284                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-285                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-161                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-286                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-287                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-288                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-162               [1, 2048, 1, 1]           --
# ├─Linear: 1-36                                [1, 2048]                 (recursive)
# ├─Sequential: 1-37                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-163                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-164                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-165                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-166                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-167                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-289                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-290                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-291                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-168                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-292                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-293                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-294                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-295                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-169                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-296                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-297                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-298                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-299                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-300                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-301                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-170                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-302                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-303                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-304                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-171               [1, 2048, 1, 1]           --
# ├─Linear: 1-38                                [1, 2048]                 (recursive)
# ├─Sequential: 1-39                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-172                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-173                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-174                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-175                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-176                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-305                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-306                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-307                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-177                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-308                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-309                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-310                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-311                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-178                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-312                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-313                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-314                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-315                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-316                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-317                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-179                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-318                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-319                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-320                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-180               [1, 2048, 1, 1]           --
# ├─Linear: 1-40                                [1, 2048]                 (recursive)
# ├─Sequential: 1-41                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-181                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-182                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-183                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-184                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-185                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-321                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-322                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-323                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-186                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-324                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-325                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-326                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-327                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-187                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-328                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-329                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-330                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-331                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-332                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-333                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-188                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-334                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-335                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-336                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-189               [1, 2048, 1, 1]           --
# ├─Linear: 1-42                                [1, 2048]                 (recursive)
# ├─Sequential: 1-43                            [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-190                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-191                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-192                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-193                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-194                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-337                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-338                 [1, 256, 56, 56]          (recursive)
# ...
# │    │    └─Bottleneck: 3-849                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-850                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-851                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-483                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-852                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-853                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-854                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-855                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-484                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-856                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-857                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-858                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-859                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-860                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-861                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-485                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-862                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-863                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-864                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-486               [1, 2048, 1, 1]           --
# ├─Linear: 1-108                               [1, 2048]                 (recursive)
# ├─Sequential: 1-109                           [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-487                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-488                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-489                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-490                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-491                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-865                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-866                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-867                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-492                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-868                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-869                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-870                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-871                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-493                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-872                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-873                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-874                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-875                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-876                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-877                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-494                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-878                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-879                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-880                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-495               [1, 2048, 1, 1]           --
# ├─Linear: 1-110                               [1, 2048]                 (recursive)
# ├─Sequential: 1-111                           [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-496                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-497                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-498                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-499                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-500                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-881                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-882                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-883                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-501                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-884                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-885                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-886                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-887                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-502                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-888                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-889                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-890                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-891                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-892                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-893                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-503                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-894                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-895                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-896                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-504               [1, 2048, 1, 1]           --
# ├─Linear: 1-112                               [1, 2048]                 (recursive)
# ├─Sequential: 1-113                           [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-505                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-506                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-507                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-508                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-509                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-897                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-898                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-899                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-510                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-900                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-901                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-902                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-903                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-511                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-904                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-905                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-906                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-907                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-908                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-909                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-512                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-910                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-911                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-912                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-513               [1, 2048, 1, 1]           --
# ├─Linear: 1-114                               [1, 2048]                 (recursive)
# ├─Sequential: 1-115                           [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-514                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-515                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-516                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-517                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-518                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-913                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-914                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-915                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-519                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-916                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-917                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-918                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-919                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-520                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-920                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-921                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-922                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-923                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-924                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-925                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-521                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-926                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-927                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-928                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-522               [1, 2048, 1, 1]           --
# ├─Linear: 1-116                               [1, 2048]                 (recursive)
# ├─Sequential: 1-117                           [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-523                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-524                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-525                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-526                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-527                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-929                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-930                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-931                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-528                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-932                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-933                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-934                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-935                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-529                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-936                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-937                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-938                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-939                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-940                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-941                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-530                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-942                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-943                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-944                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-531               [1, 2048, 1, 1]           --
# ├─Linear: 1-118                               [1, 2048]                 (recursive)
# ├─Sequential: 1-119                           [1, 2048, 1, 1]           (recursive)
# │    └─Conv2d: 2-532                          [1, 64, 112, 112]         (recursive)
# │    └─BatchNorm2d: 2-533                     [1, 64, 112, 112]         (recursive)
# │    └─ReLU: 2-534                            [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-535                       [1, 64, 56, 56]           --
# │    └─Sequential: 2-536                      [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-945                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-946                 [1, 256, 56, 56]          (recursive)
# │    │    └─Bottleneck: 3-947                 [1, 256, 56, 56]          (recursive)
# │    └─Sequential: 2-537                      [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-948                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-949                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-950                 [1, 512, 28, 28]          (recursive)
# │    │    └─Bottleneck: 3-951                 [1, 512, 28, 28]          (recursive)
# │    └─Sequential: 2-538                      [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-952                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-953                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-954                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-955                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-956                 [1, 1024, 14, 14]         (recursive)
# │    │    └─Bottleneck: 3-957                 [1, 1024, 14, 14]         (recursive)
# │    └─Sequential: 2-539                      [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-958                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-959                 [1, 2048, 7, 7]           (recursive)
# │    │    └─Bottleneck: 3-960                 [1, 2048, 7, 7]           (recursive)
# │    └─AdaptiveAvgPool2d: 2-540               [1, 2048, 1, 1]           --
# ├─Linear: 1-120                               [1, 2048]                 (recursive)
# ├─LSTM: 1-121                                 [1, 60, 2048]             33,570,816
# ├─Dropout: 1-122                              [1, 60, 2048]             --
# ├─Linear: 1-123                               [1, 1]                    2,049
# ===============================================================================================
# Total params: 60,749,121
# Trainable params: 60,749,121
# Non-trainable params: 0
# Total mult-adds (G): 255.98
# ===============================================================================================
# Input size (MB): 36.13
# Forward/backward pass size (MB): 13826.46
# Params size (MB): 243.00
# Estimated Total Size (MB): 14105.58
# ===============================================================================================

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device):
    model.train()
    cur_loss = 0.0
    all_preds = []
    all_labels = []
    scaler = torch.cuda.amp.GradScaler()
    for video_tensors, labels in dataloader:
        video_tensors, labels = video_tensors.to(device), labels.to(device)
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(video_tensors).squeeze()
            loss = loss_fn(outputs, labels.float())
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        cur_loss += loss.item() * video_tensors.size(0)
        predicted = (torch.sigmoid(outputs) > 0.5).float()
        all_preds.append(predicted.cpu())
        all_labels.append(labels.cpu())
    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)
    train_loss = cur_loss / len(dataloader.dataset)
    accuracy = (all_preds == all_labels).sum().item() / len(all_labels)
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds, zero_division=0)
    f1 = f1_score(all_labels, all_preds, zero_division=0)
    conf_matrix = confusion_matrix(all_labels, all_preds)
    return train_loss, accuracy, precision, recall, f1, conf_matrix

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device):
    model.eval()
    cur_loss = 0.0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for video_tensors, labels in dataloader:
            video_tensors, labels = video_tensors.to(device), labels.to(device)
            outputs = model(video_tensors).squeeze()
            loss = loss_fn(outputs, labels.float())
            cur_loss += loss.item() * video_tensors.size(0)
            predicted = (torch.sigmoid(outputs) > 0.5).float()
            all_preds.append(predicted.cpu())
            all_labels.append(labels.cpu())
    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)
    test_loss = cur_loss / len(dataloader.dataset)
    accuracy = (all_preds == all_labels).sum().item() / len(all_labels)
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds, zero_division=0)
    f1 = f1_score(all_labels, all_preds, zero_division=0)
    conf_matrix = confusion_matrix(all_labels, all_preds)
    return test_loss, accuracy, precision, recall, f1, conf_matrix

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          loss_fn: torch.nn.Module,
          optimizer: torch.optim.Optimizer,
          device: torch.device,
          epochs: int = 5):
    results = {
        "train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": [],
        "train_precision": [],
        "train_recall": [],
        "train_f1": [],
        "test_precision": [],
        "test_recall": [],
        "test_f1": []
    }
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc, train_precision, train_recall, train_f1, train_conf_matrix = train_step(
            model=model,
            dataloader=train_dataloader,
            loss_fn=loss_fn,
            optimizer=optimizer,
            device=device
        )
        test_loss, test_acc, test_precision, test_recall, test_f1, test_conf_matrix = test_step(
            model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn,
            device=device
        )
        print(
            f"Epoch: {epoch + 1} | "
            f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
            f"Train Precision: {train_precision:.4f} | Train Recall: {train_recall:.4f} | Train F1: {train_f1:.4f} | "
            f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f} | "
            f"Test Precision: {test_precision:.4f} | Test Recall: {test_recall:.4f} | Test F1: {test_f1:.4f}"
        )
        print(f"Train Confusion Matrix:\n{train_conf_matrix}")
        print(f"Test Confusion Matrix:\n{test_conf_matrix}")
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["train_precision"].append(train_precision)
        results["train_recall"].append(train_recall)
        results["train_f1"].append(train_f1)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)
        results["test_precision"].append(test_precision)
        results["test_recall"].append(test_recall)
        results["test_f1"].append(test_f1)
    return results

# %%
import torch.optim as optim

loss_fn = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_0.parameters(),
                       lr=1e-5,
                       weight_decay=1e-6)

# %%
NUM_EPOCHS = 10

from timeit import default_timer as timer

start = timer()

model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        loss_fn=loss_fn,
                        optimizer=optimizer,
                        device=device,
                        epochs=NUM_EPOCHS)

model_0_results

end = timer()

print(f"Time taken to train model_0: {end-start: .3f} seconds")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | Train Loss: 0.4211 | Train Acc: 0.7753 | Train Precision: 0.7548 | Train Recall: 0.8610 | Train F1: 0.8044 | Test Loss: 0.2767 | Test Acc: 0.9147 | Test Precision: 0.8649 | Test Recall: 0.9968 | Test F1: 0.9262
# Train Confusion Matrix:
# [[1453  696]
#  [ 346 2143]]
# Test Confusion Matrix:
# [[440  97]
#  [  2 621]]
# Epoch: 2 | Train Loss: 0.1131 | Train Acc: 0.9590 | Train Precision: 0.9607 | Train Recall: 0.9630 | Train F1: 0.9619 | Test Loss: 0.1869 | Test Acc: 0.9414 | Test Precision: 0.9173 | Test Recall: 0.9791 | Test F1: 0.9472
# Train Confusion Matrix:
# [[2051   98]
#  [  92 2397]]
# Test Confusion Matrix:
# [[482  55]
#  [ 13 610]]
# Epoch: 3 | Train Loss: 0.0762 | Train Acc: 0.9730 | Train Precision: 0.9728 | Train Recall: 0.9771 | Train F1: 0.9749 | Test Loss: 0.0646 | Test Acc: 0.9750 | Test Precision: 1.0000 | Test Recall: 0.9535 | Test F1: 0.9762
# Train Confusion Matrix:
# [[2081   68]
#  [  57 2432]]
# Test Confusion Matrix:
# [[537   0]
#  [ 29 594]]
# Epoch: 4 | Train Loss: 0.0580 | Train Acc: 0.9815 | Train Precision: 0.9823 | Train Recall: 0.9831 | Train F1: 0.9827 | Test Loss: 0.0334 | Test Acc: 0.9888 | Test Precision: 0.9796 | Test Recall: 1.0000 | Test F1: 0.9897
# Train Confusion Matrix:
# [[2105   44]
#  [  42 2447]]
# Test Confusion Matrix:
# [[524  13]
#  [  0 623]]
# Epoch: 5 | Train Loss: 0.0460 | Train Acc: 0.9853 | Train Precision: 0.9852 | Train Recall: 0.9875 | Train F1: 0.9864 | Test Loss: 0.6310 | Test Acc: 0.8009 | Test Precision: 0.7295 | Test Recall: 1.0000 | Test F1: 0.8436
# Train Confusion Matrix:
# [[2112   37]
#  [  31 2458]]
# Test Confusion Matrix:
# [[306 231]
#  [  0 623]]
# Epoch: 6 | Train Loss: 0.0378 | Train Acc: 0.9886 | Train Precision: 0.9868 | Train Recall: 0.9920 | Train F1: 0.9894 | Test Loss: 0.1950 | Test Acc: 0.9560 | Test Precision: 0.9307 | Test Recall: 0.9920 | Test F1: 0.9604
# Train Confusion Matrix:
# [[2116   33]
#  [  20 2469]]
# Test Confusion Matrix:
# [[491  46]
#  [  5 618]]
# Epoch: 7 | Train Loss: 0.0303 | Train Acc: 0.9909 | Train Precision: 0.9896 | Train Recall: 0.9936 | Train F1: 0.9916 | Test Loss: 0.0825 | Test Acc: 0.9810 | Test Precision: 0.9855 | Test Recall: 0.9791 | Test F1: 0.9823
# Train Confusion Matrix:
# [[2123   26]
#  [  16 2473]]
# Test Confusion Matrix:
# [[528   9]
#  [ 13 610]]
# Epoch: 8 | Train Loss: 0.0301 | Train Acc: 0.9916 | Train Precision: 0.9892 | Train Recall: 0.9952 | Train F1: 0.9922 | Test Loss: 0.3642 | Test Acc: 0.9310 | Test Precision: 0.8884 | Test Recall: 0.9968 | Test F1: 0.9395
# Train Confusion Matrix:
# [[2122   27]
#  [  12 2477]]
# Test Confusion Matrix:
# [[459  78]
#  [  2 621]]
# Epoch: 9 | Train Loss: 0.0123 | Train Acc: 0.9961 | Train Precision: 0.9960 | Train Recall: 0.9968 | Train F1: 0.9964 | Test Loss: 0.3582 | Test Acc: 0.9422 | Test Precision: 0.9029 | Test Recall: 1.0000 | Test F1: 0.9490
# Train Confusion Matrix:
# [[2139   10]
#  [   8 2481]]
# Test Confusion Matrix:
# [[470  67]
#  [  0 623]]
# Epoch: 10 | Train Loss: 0.0262 | Train Acc: 0.9929 | Train Precision: 0.9924 | Train Recall: 0.9944 | Train F1: 0.9934 | Test Loss: 0.2802 | Test Acc: 0.9328 | Test Precision: 0.9225 | Test Recall: 0.9551 | Test F1: 0.9385
# Train Confusion Matrix:
# [[2130   19]
#  [  14 2475]]
# Test Confusion Matrix:
# [[487  50]
#  [ 28 595]]
# Time taken to train model_0:  6781.665 seconds

# %%
import matplotlib.pyplot as plt
from typing import Dict, List

def plot_loss_curves(results: Dict[str, List[float]]):

  loss = results["train_loss"]
  test_loss = results["test_loss"]

  accuracy = results["train_acc"]
  test_accuracy = results["test_acc"]

  epochs = range(len(results["train_loss"]))

  plt.figure(figsize=(15, 7))

  plt.subplot(1, 2, 1)
  plt.plot(epochs, loss, label="train_loss")
  plt.plot(epochs, test_loss, label="test_loss")
  plt.title("Loss")
  plt.xlabel("Epochs")
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.plot(epochs, accuracy, label='train_accuracy')
  plt.plot(epochs, test_accuracy, label='test_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(model_0_results)
